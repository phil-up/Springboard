# %% [markdown]
# In this project we will perform an exploratory data analysis and machine learning model of the adult income available on Kraggle (https://www.kaggle.com/datasets/wenruliu/adult-income-dataset?select=adult.csv) to find interesting insights from the data.

# %%
#import libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('adult.csv')

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
#check and drop duplicates 
data = data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48790 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48790 non-null  int64
#  1   workclass        48790 non-null  object
#  2   fnlwgt           48790 non-null  int64
#  3   education        48790 non-null  object
#  4   educational-num  48790 non-null  int64
#  5   marital-status   48790 non-null  object
#  6   occupation       48790 non-null  object
#  7   relationship     48790 non-null  object
#  8   race             48790 non-null  object
#  9   gender           48790 non-null  object
#  10  capital-gain     48790 non-null  int64
#  11  capital-loss     48790 non-null  int64
#  12  hours-per-week   48790 non-null  int64
#  13  native-country   48790 non-null  object
#  14  income           48790 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 6.0+ MB

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48790.000000  4.879000e+04     48790.000000  48790.000000
# mean      38.652798  1.896690e+05        10.078807   1080.217688
# std       13.708493  1.056172e+05         2.570046   7455.905921
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175550e+05         9.000000      0.000000
# 50%       37.000000  1.781385e+05        10.000000      0.000000
# 75%       48.000000  2.376062e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48790.000000    48790.000000
# mean      87.595573       40.425886
# std      403.209129       12.392729
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
#check for missing values
data = data.replace("?", np.nan)

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2795
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2805
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      856
# income                0
# dtype: int64

# %%
#drop missing values
data_clean = data.dropna()
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              45175 non-null  int64
#  1   workclass        45175 non-null  object
#  2   fnlwgt           45175 non-null  int64
#  3   education        45175 non-null  object
#  4   educational-num  45175 non-null  int64
#  5   marital-status   45175 non-null  object
#  6   occupation       45175 non-null  object
#  7   relationship     45175 non-null  object
#  8   race             45175 non-null  object
#  9   gender           45175 non-null  object
#  10  capital-gain     45175 non-null  int64
#  11  capital-loss     45175 non-null  int64
#  12  hours-per-week   45175 non-null  int64
#  13  native-country   45175 non-null  object
#  14  income           45175 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.5+ MB

# %% [markdown]
# # Data Analysis and Visualization

# %%
#overview of the dataset
_=data_clean.hist(bins=20, figsize=(7,8))

# %%
data_clean['workclass'].value_counts().plot(kind='bar', figsize=(6,4))
plt.figure()

data_clean['education'].value_counts().plot(kind='bar', figsize=(6, 4))
plt.figure()

data_clean['marital-status'].value_counts().plot(kind='bar', figsize=(6,4))
plt.figure()

data_clean['occupation'].value_counts().plot(kind='bar', figsize=(6,4))
plt.figure()

data_clean['relationship'].value_counts().plot(kind='bar', figsize=(6,4))
plt.figure()

data_clean['race'].value_counts().plot(kind='bar', figsize=(6,4))
plt.figure()

data_clean['gender'].value_counts().plot(kind='bar', figsize=(6,4))
plt.figure()

data_clean['native-country'].value_counts().plot(kind='bar', figsize=(6,4))
plt.figure()

data_clean['income'].value_counts().plot(kind='bar', figsize=(6,4))
plt.figure()

# %%
#heatmap and correlation 
sns.heatmap(data_clean.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
g = sns.catplot(
    data=data_clean, kind="bar",
    x="gender", y="age", hue="income",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)

# %%
sns.catplot(
    data=data_clean, kind="bar",
    x="marital-status", y="age", hue="income",
    ci="sd", palette="dark", alpha=.6, height = 10, aspect = 2)

# %%
sns.catplot(
    data=data_clean, kind="bar",
    x="relationship", y="age", hue="income",
    ci="sd", palette="dark", alpha=.6, height = 10, aspect = 2
)

# %%
ax = sns.countplot(x="relationship", hue="income", data=data_clean)

# %%
fig, ax = plt.subplots(figsize=(12,5))
_ = sns.countplot(x="marital-status", hue="income", data=data_clean, ax=ax)

# %%
fig,ax = plt.subplots()

for (i, d) in data_clean.groupby('income'):
    d['age'].hist(alpha=0.7, ax=ax, label=i)

ax.legend()

# %%
fig,ax = plt.subplots()

for (i, d) in data_clean.groupby('income'):
    d['capital-gain'].hist(alpha=0.7, ax=ax, label=i)

ax.legend()

# %%
fig,ax = plt.subplots()

for (i, d) in data_clean.groupby('income'):
    d['educational-num'].hist(alpha=0.7, ax=ax, label=i)

ax.legend()

# %%
fig,ax = plt.subplots()

for (i, d) in data_clean.groupby('income'):
    d['hours-per-week'].hist(alpha=0.7, ax=ax, label=i)

ax.legend()

# %% [markdown]
# # Modeling

# %%
from pycaret.classification import *

# %%
#setup dataset
clf1 = setup(data = data_clean, target='income', session_id=123)
# Out:
# <style type="text/css">
# #T_3ff3d_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3ff3d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ff3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ff3d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3ff3d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3ff3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ff3d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3ff3d_row1_col1" class="data row1 col1" >income</td>
#     </tr>
#     <tr>
#       <th id="T_3ff3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3ff3d_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_d549f_ th {
#   text-align: left;
# }
# ...

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_83735_row10_col0, #T_83735_row10_col1, #T_83735_row10_col2, #T_83735_row10_col3, #T_83735_row10_col4, #T_83735_row10_col5, #T_83735_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_83735_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83735_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83735_row0_col0" class="data row0 col0" >0.8580</td>
#       <td id="T_83735_row0_col1" class="data row0 col1" >0.9172</td>
# ...

# %%
tuned_lightgbm = tune_model(lightgbm)
# Out:
# <style type="text/css">
# #T_43d1a_row10_col0, #T_43d1a_row10_col1, #T_43d1a_row10_col2, #T_43d1a_row10_col3, #T_43d1a_row10_col4, #T_43d1a_row10_col5, #T_43d1a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_43d1a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43d1a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43d1a_row0_col0" class="data row0 col0" >0.8568</td>
#       <td id="T_43d1a_row0_col1" class="data row0 col1" >0.9173</td>
# ...

# %%
plot_model(tuned_lightgbm, plot = 'confusion_matrix')

# %%
plot_model(tuned_lightgbm, plot = 'class_report')

# %%
plot_model(tuned_lightgbm, plot = 'auc')

# %%
plot_model(tuned_lightgbm, plot = 'feature')
# Out:
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# ...

# %% [markdown]
# fnlwgt = final weight

# %%
plot_model(tuned_lightgbm, plot = 'error')

# %%
predict_model(tuned_lightgbm);
# Out:
# <style type="text/css">
# </style>
# <table id="T_2214f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2214f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2214f_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2214f_row0_col1" class="data row0 col1" >0.8670</td>
#       <td id="T_2214f_row0_col2" class="data row0 col2" >0.9240</td>
# ...
