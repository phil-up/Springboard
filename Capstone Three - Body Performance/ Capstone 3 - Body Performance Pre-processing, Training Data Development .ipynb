# %% [markdown]
# # Pre-processing, Training Data Development

# %%
from pycaret.classification import *

# %%
body_performance = pd.read_csv('bodyPerformance.csv')

# %%
clf1 = setup(data = body_performance, target='class', session_id=123)
# Out:
# <style type="text/css">
# #T_bdece_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bdece_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdece_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdece_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_bdece_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bdece_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bdece_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bdece_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_bdece_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bdece_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_98f1f_ th {
#   text-align: left;
# }
# ...

# %%
clf1 = setup(data = body_performance, target='class', session_id=123, normalize=True, normalize_method='minmax')
# Out:
# <style type="text/css">
# #T_2bc69_row29_col1, #T_2bc69_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2bc69_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bc69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bc69_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_2bc69_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2bc69_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2bc69_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2bc69_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_2bc69_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_89d55_ th {
#   text-align: left;
# }
# ...

# %%
clf1 = setup(data = body_performance, target='class', session_id=123, normalize=True, normalize_method='zscore')
# Out:
# <style type="text/css">
# #T_3d095_row29_col1, #T_3d095_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3d095_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d095_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d095_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3d095_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3d095_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d095_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3d095_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_3d095_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_420fc_ th {
#   text-align: left;
# }
# ...

# %%
clf1 = setup(data = body_performance, target='class', session_id=123, normalize=True, normalize_method='maxabs')
# Out:
# <style type="text/css">
# #T_fa2c6_row29_col1, #T_fa2c6_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fa2c6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa2c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa2c6_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_fa2c6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fa2c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa2c6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fa2c6_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_fa2c6_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_0b590_ th {
#   text-align: left;
# }
# ...

# %%
clf1 = setup(data = body_performance, target='class', session_id=123, normalize=True, normalize_method='robust')
# Out:
# <style type="text/css">
# #T_df012_row29_col1, #T_df012_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_df012_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df012_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df012_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_df012_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_df012_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_df012_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_df012_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_df012_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_d0c2e_ th {
#   text-align: left;
# }
# ...

# %%
clf1 = setup(data = body_performance, target='class', session_id=123, normalize=True, normalize_method='robust', fix_imbalance=True)
# Out:
# <style type="text/css">
# #T_7a8bf_row29_col1, #T_7a8bf_row44_col1, #T_7a8bf_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7a8bf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a8bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a8bf_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7a8bf_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7a8bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a8bf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7a8bf_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_7a8bf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_a7f50_ th {
#   text-align: left;
# }
# ...

# %%
clf1 = setup(data = body_performance, target='class', session_id=123, normalize=True, normalize_method='robust', remove_outliers=True)
# Out:
# <style type="text/css">
# #T_996e1_row29_col1, #T_996e1_row40_col1, #T_996e1_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_996e1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_996e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_996e1_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_996e1_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_996e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_996e1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_996e1_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_996e1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_3a2bb_ th {
#   text-align: left;
# }
# ...
